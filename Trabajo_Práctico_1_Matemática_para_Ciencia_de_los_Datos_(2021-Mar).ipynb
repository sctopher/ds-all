# %% [markdown]
# # Matemática para Ciencia de los Datos
# # Trabajo práctico 1 (TP1)
#
# María Auxiliadora Mora
#
# Instituto Tecnológico de Costa Rica,
#
# Medio de entrega:  TecDigital.
#
# Entregables: Un archivo jupyter
#
# Modo de trabajo: Parejas
#
# ---
# Objetivo: El presente trabajo práctico tiene como objetivo repasar aspectos básicos del álgebra lineal, como sistemas lineales y vectores, usando el lenguaje Python, con la librería Pytorch.
#
# Utilice celdas de texto para explicaciones amplias de su respuesta y en las celdas de código, además de programar en Python con la librería Pytorch, documente su código con comentarios explicativos de lo que realiza el programa.
#
# En cada función, incluya un encabezado que documente las entradas, salidas y lo que realiza la función.

# %% [markdown]
# ---
#
# **Pregunta 1 (15 puntos, 5 pts c/u)**
#
# Demuestre de forma matemática (sin programar) si los siguientes sistemas $L\left\{ \cdot\right\}$  (con entrada $u(t)$ y salida $g(t)$) son lineales o no lineales. Si los sistemas son no lineales puede demostrarlo por contra-ejemplo.
#
#   a)$g\left(t\right)=\log _{10} u(t)$
#
#   b)$g\left(t\right)= |u(t) |$
#
#   c) $g\left(t\right)= \tanh(u(t))=\frac{e^{u(t)}-e^{-u(t)}}{e^{u(t)}+e^{-u(t)}} $
#
# Donde | | corresponde al valor absoluto.

# %% [markdown]
# ---
#
# **Pregunta 2 (15 puntos, 5 pts c/u)**
#
# Sean los siguientes vectores:
#
# $\vec{v}_{1}=\begin{bmatrix}-0.3\\
# 0.8\\
# 0.1
# \end{bmatrix}, \vec{v}_{2}=\begin{bmatrix}0.5\\
# 0.2\\
# 0.4
# \end{bmatrix} y \vec{v}_{3}=\begin{bmatrix}\frac{1}{\sqrt{2}}\\
# \frac{-1}{\sqrt{2}}\\
# 0
# \end{bmatrix} $
#
# Resuelva los siguientes ejercicios:
#
# a) Graficación de vectores. Usando Python grafique juntos los vectores anteriores (puede utilizar la función quiver).
#
# b) Implemente una función en Pytorch que calcule el ángulo en grados entre vectores. Pruebe su función calculando el ángulo entre los vectores $\vec{v}_{1}y \vec{v}_{2,}\vec{v}_{2}y \vec{v}_{3}$. Implemente la fórmula en Pytorch, sin usar las funciones correspondientes de la biblioteca (es decir deben programar la fórmula del cálculo del ángulo).
#
# c) Calcule la distancia en $\ell_{1}$y$\ell_{2}$ entre los vectores $\vec{v}_{1}$y$\vec{v}_{2,}\vec{v}_{2}y\vec{v}_{3}$, implementando la fórmula en Pytorch, sin usar las funciones correspondientes de la biblioteca. Compare el resultado obtenido con el uso de la función torch.norm.

# %% [markdown]
# ---
#
# **Pregunta 3 (10 puntos, 5 pts c/u)**
#
# Propiedades del producto punto: demuestre lo siguiente. Muéstrelo con una implementación en Pytorch, usando como entrada arreglos de 50 elementos generados al azar. Demuestre el cumplimiento o no de la propiedad con un ejemplo o contraejemplo.
#
# a) Conmutatividad del producto punto, esto es $\vec{u}\cdot\vec{v}=\vec{v}\cdot\vec{u}$
#
# b) No asociatividad del producto punto, es decir $\vec{u}\cdot\left(\vec{v}\cdot\vec{w}\right)\neq\left(\vec{u}\cdot\vec{v}\right)\cdot\vec{w}$

# %% [markdown]
# ---
#
# **Pregunta 4 (5 puntos)**
#
# a) Implemente una función en Pytorch que calcule la dirección de un vector en $\mathbb{R}^n$.
